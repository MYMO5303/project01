# %%
import pandas as pd

# %%
# !pip install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
pd.read_excel('001051370.xlsx')
df= pd.read_excel('001051370.xlsx')

# %%
df
# Out:
#     Unnamed: 0 性別・年齢階級別、自殺者数詳細（職業） Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0          NaN             令和4年暫定値        NaN        NaN         NaN
# 1          NaN               （発見日）        NaN        NaN         NaN
# 2          NaN                 NaN        NaN        NaN         NaN
# 3          NaN                 NaN        NaN        NaN         NaN
# 4          NaN                 NaN        NaN        NaN         NaN
# 5          NaN                 NaN        NaN        NaN         NaN
# 6          NaN                  全国          計        NaN         NaN
# 7          NaN                 NaN        NaN        NaN         NaN
# 8          NaN                 NaN        NaN        NaN         NaN
# 9          NaN                 NaN        NaN       ～19歳         NaN
# 10         NaN                 NaN        NaN        NaN         NaN
# 11         NaN                 NaN        NaN        NaN         NaN
# 12         NaN                 NaN        NaN     20～29歳         NaN
# ...
